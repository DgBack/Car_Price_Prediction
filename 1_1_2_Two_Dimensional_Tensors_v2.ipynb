# %% [markdown]
# <a href="https://colab.research.google.com/github/DgBack/Car_Price_Prediction/blob/main/1_1_2_Two_Dimensional_Tensors_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Two-Dimensional Tensors

# %% [markdown]
# # **Preparation**

# %% [markdown]
# Ta cần khai báo và cài đặt một số thư viện cần thiết để chuẩn bị cho việc tính toán

# %%
# Đây là một số thư viện căn bản 

import numpy as np 
import torch 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# # **Types and Shape**

# %% [markdown]
# Nhìn chung về vấn đề việc gọi hàm hay là khởi tạo tensor khá là giống với phần cũ.

# %%
twoD_list = [[11, 12, 13], [21, 22, 23], [31, 32, 33]]
twoD_tensor = torch.tensor(twoD_list)
print('The new tensor 2D :', twoD_tensor)

# %% [markdown]
# Đây là cách thông dụng nhất để tạo một tensor 2D.
#
# Tiếp đó chúng ta sẽ cùng dùng thử lện tensor_obj.ndimension(), tensor_obj.shape, tensor_obj.size()

# %%
# Try tensor_obj.ndimension(), tensor_obj.shape, tensor_obj.size()

print('The dimenson of twoD_tensor: ', twoD_tensor.ndimension())  # Lệnh này dùng để kiểm tra số chiều của ma trận 
print('The shape of twoD_tensor: ', twoD_tensor.shape)  # Hai câu lệnh shape và size có cùng chung một aoutput nhwung có lẽ khác nhau về hàm và cách gọi 
print('The size of twoD_tensor: ', twoD_tensor.size())
print('The number of elements in twoD_tensor: ', twoD_tensor.numel())  # Câu lệnh này dùng để kiểm tra số phần tử của ma trận đó

# %% [markdown]
# Bây giò chúng ta cần thử chuyển từ tensor về numpy và ngược lại

# %%
# Convert tensor to numpy array; Convert numpy array to tensor

twoD_numpy = twoD_tensor.numpy()
print("Tensor -> Numpy Array:")
print("The numpy array after converting: ", twoD_numpy)
print("Type after converting: ", twoD_numpy.dtype)

print("================================================")

new_twoD_tensor = torch.from_numpy(twoD_numpy)
print("Numpy Array -> Tensor:")
print("The tensor after converting:", new_twoD_tensor)
print("Type after converting: ", new_twoD_tensor.dtype)

# %% [markdown]
# Và thông thường chúng ta còn phải làm việc với kiểu dữ liệu trong pandas, vì thế chúng ta cũng nên tìm hiểu qua về cách chuyển trong hai loại này.

# %%
df = pd.DataFrame({'a': [11, 12, 13], 'b' : [12, 22, 312]})

print('PandasFrame Data to numpy: ', df.values)
print('Type of this after converting: ', df.values.dtype)

print("================================================")

new_tensor = torch.from_numpy(df.values)
print("Tensor AFTER converting: ", new_tensor)
print("Type AFTER converting: ", new_tensor.dtype)

# %% [markdown]
# Bài tập : Chuyển dữ liệu dạng Pandas sau thành dạng tensor

# %%
# Practice: try to convert Pandas Series to tensor

df = pd.DataFrame({'A':[11, 33, 22],'B':[3, 3, 2]})

new_tensor = torch.tensor(df.values)

print('Data after change: ', new_tensor)
print('The type of data after change: ', new_tensor.dtype)

# %% [markdown]
# # **Indexing and Slicing**

# %% [markdown]
# Chúng ta có thể dễ dàng sử dụng ngoặc vuông để truy cập đến các phần tử trong tensor 2D, Dưới đây là ví dụ của một tensor 3x3 :

# %% [markdown]
# ![1.2index1.png](data:image/png;base64,...)

# %% [markdown]
# Và để truy cập phần tử nào chúng ta chỉ việc gọi với cú pháp tensor_obj[số hàng][số cột]. Nhưng có một điểm cần lưu ý là ma trận của chúng ta có cá chỉ số được tính từ 0 đến n-1 .

# %%
# Use tensor_obj[row, column] and tensor_obj[row][column] to access certain position

tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print("What is the value on 2nd-row 3rd-column? ", tensor_example[1, 2])
print("What is the value on 2nd-row 3rd-column? ", tensor_example[1][2])

# %%
print(tensor_example[0][0])

# %% [markdown]
# Bây giờ chúng ta sẽ thử slicing với 2D tensor

# %%
# Use tensor_obj[begin_row_number: end_row_number, begin_column_number: end_column number] 
# and tensor_obj[row][begin_column_number: end_column number] to do the slicing

tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print("What is the value on 1st-row first two columns? ", tensor_example[0, 0:2])
print("What is the value on 1st-row first two columns? ", tensor_example[0][0:2])

# %%
tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
sliced_tensor_example = tensor_example[1:3]
print("1. Slicing step on tensor_example: ")
print("Result after tensor_example[1:3]: ", sliced_tensor_example)
print("Dimension after tensor_example[1:3]: ", sliced_tensor_example.ndimension())
print("================================================")
print("2. Pick an index on sliced_tensor_example: ")
print("Result after sliced_tensor_example[1]: ", sliced_tensor_example[1])
print("Dimension after sliced_tensor_example[1]: ", sliced_tensor_example[1].ndimension())
print("================================================")
print("3. Combine these step together:")
print("Result: ", tensor_example[1:3][1])
print("Dimension: ", tensor_example[1:3][1].ndimension())

# %%
# Use tensor_obj[begin_row_number: end_row_number, begin_column_number: end_column number] 

tensor_example = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print("What is the value on 3rd-column last two rows? ", tensor_example[1:3, 0:2])

# %% [markdown]
# Bài tập

# %%
# Practice: Use slice and index to change the values on the matrix tensor_ques.

tensor_ques = torch.tensor([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
tensor_ques[1:3, 1] = 0 
print(tensor_ques)

# %% [markdown]
# # **Tensor Operations**

# %% [markdown]
# Tensor Addition

# %%
# Cộng hai ma trận như bình thường 

X = torch.tensor([[1, 0],[0, 1]]) 
Y = torch.tensor([[2, 1],[1, 2]])
X_plus_Y = X + Y
print("The result of X + Y: ", X_plus_Y)

# %% [markdown]
# Scalar Multiplication

# %%
# Calculate 2 * [[2, 1], [1, 2]]

Y = torch.tensor([[2, 1], [1, 2]]) 
two_Y = 2 * Y
print("The result of 2Y: ", two_Y)

# %% [markdown]
# Element-wise Product/Hadamard Product

# %%
# Calculate [[1, 0], [0, 1]] * [[2, 1], [1, 2]]

X = torch.tensor([[1, 0], [0, 1]])
Y = torch.tensor([[2, 1], [1, 2]]) 
X_times_Y = X * Y
print("The result of X * Y: ", X_times_Y)

# %% [markdown]
# Matrix Multiplication

# %%
# Calculate [[0, 1, 1], [1, 0, 1]] * [[1, 1], [1, 1], [-1, 1]]

A = torch.tensor([[0, 1, 1], [1, 0, 1]])
B = torch.tensor([[1, 1], [1, 1], [-1, 1]])
A_times_B = torch.mm(A,B)
print("The result of A * B: ", A_times_B)

# %%
# bài tập 
X = torch.tensor([[0, 1], [1, 2]])
Y = torch.tensor([[-1, -2, 0], [2, 1, 2]])
X_times_Y = torch.mm(X, Y)
print("The result of X * Y: ", X_times_Y)
